# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [2,4,5]

plt.plot(x,y)
plt.title('chart title')
plt.xlabel('x label')
plt.ylabel('y label')
plt.show()

# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
import pandas as pd

df = pd.read_excel('s3://lowe-241-2023-python/house_price.xls')
df['build_in'] = pd.to_datetime(df['built_in'], format= '%Y')
df.head()
# Out:
#     ID   price  bedroom  bathroom          house_type  lot_size  built_in  \
# 0  993  229900        3         2  single-family home     10018      2002
# 1  994  149900        4         2  single-family home      8712      1975
# 2  995  229900        3         2  single-family home     13504      1988
# 3  996  359000        5         4  single-family home     10130      1997
# 4  999  394000        3         2  single-family home     18295      2001
#
#    area  days  views   build_in
# 0  1541    77   1357 2002-01-01
# 1  1810     5   1282 1975-01-01
# 2  1456    76    947 1988-01-01
# 3  2903    79    951 1997-01-01
# 4  2616    73    709 2001-01-01

# %%
df.plot(x='built_in',y='price')
# Out:
# <AxesSubplot: xlabel='built_in'>

# %%
avg_price_year = df.groupby('built_in')['price'].mean()

avg_price_year.plot()
# Out:
# <AxesSubplot: xlabel='built_in'>

# %%
df['price'].hist()
# Out:
# <AxesSubplot: >

# %%
avg_price_type = df.groupby('house_type')['price'].mean()

avg_price_type.plot.bar()
# Out:
# <AxesSubplot: xlabel='house_type'>

# %%
count_per_type = df['house_type'].value_counts()

count_per_type.plot.bar()
# Out:
# <AxesSubplot: >

# %%
df.plot.scatter(x= 'area', y='price')
# Out:
# <AxesSubplot: xlabel='area', ylabel='price'>
